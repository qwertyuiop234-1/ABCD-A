# %% [markdown]
# <a href="https://colab.research.google.com/github/qwertyuiop234-1/ABCD-A/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EA%B8%B0%EC%B4%88_20250307.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1print("test")
# Out:
#   File "<ipython-input-3-780d3892ad39>", line 1
#     1print("test")
#     ^
# SyntaxError: invalid decimal literal
